# %% [markdown]
# # 0. 数据导入

# %%
# ==================== 基础数据处理库 ====================
import pandas as pd  # 数据操作和分析
import numpy as np   # 数值计算
import re            # 正则表达式处理
import json          # JSON数据解析
import warnings      # 警告处理
warnings.filterwarnings('ignore')  # 忽略警告信息
from datetime import datetime, timedelta  # 日期时间处理
import os            # 操作系统接口
import pickle        # 对象序列化
import itertools     # 迭代工具
from collections import Counter, defaultdict  # 集合操作
 
# ==================== 数据可视化库 ====================
import matplotlib.pyplot as plt  # 基础绘图
import seaborn as sns            # 高级统计图形
from matplotlib import rcParams  # 绘图参数设置
import plotly.express as px      # 交互式可视化
import plotly.graph_objects as go  # 交互式图形对象
from wordcloud import WordCloud  # 词云生成
 
# ==================== 机器学习与数据挖掘库 ====================
# 数据预处理
from sklearn.preprocessing import (
    StandardScaler, MinMaxScaler, RobustScaler,  # 特征缩放
    LabelEncoder, OneHotEncoder, OrdinalEncoder,  # 编码器
    PolynomialFeatures  # 多项式特征
)
from sklearn.impute import SimpleImputer, KNNImputer  # 缺失值处理
from sklearn.feature_selection import (
    SelectKBest, SelectFromModel, RFE,  # 特征选择
    f_classif, mutual_info_classif, chi2  # 特征选择方法
)
 
# 聚类分析
from sklearn.cluster import (
    KMeans, DBSCAN, AgglomerativeClustering,  # 聚类算法
    SpectralClustering, OPTICS
)
from sklearn.mixture import GaussianMixture  # 高斯混合模型
from sklearn.metrics import (
    silhouette_score, davies_bouldin_score,  # 聚类评估指标
    calinski_harabasz_score, adjusted_rand_score
)
 
# 分类与回归
from sklearn.linear_model import LogisticRegression, Ridge, Lasso  # 线性模型
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor  # 决策树
from sklearn.ensemble import (
    RandomForestClassifier, RandomForestRegressor,  # 随机森林
    GradientBoostingClassifier, GradientBoostingRegressor,  # 梯度提升
    AdaBoostClassifier, AdaBoostRegressor,  # AdaBoost
    VotingClassifier, StackingClassifier  # 集成方法
)
import xgboost as xgb  # XGBoost
from sklearn.svm import SVC, SVR  # 支持向量机
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor  # K近邻
from sklearn.naive_bayes import GaussianNB, MultinomialNB  # 朴素贝叶斯
from sklearn.neural_network import MLPClassifier, MLPRegressor  # 神经网络
 
# 模型评估与选择
from sklearn.model_selection import (
    train_test_split, cross_val_score, KFold,  # 数据分割与交叉验证
    StratifiedKFold, GridSearchCV, RandomizedSearchCV,  # 超参数调优
    learning_curve, validation_curve  # 学习曲线
)
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,  # 分类指标
    roc_auc_score, roc_curve, confusion_matrix, classification_report,  # 分类评估
    mean_squared_error, mean_absolute_error, r2_score,  # 回归指标
    explained_variance_score
)

# %%
df_bizs = pd.read_csv('bizs_nashville.txt', sep='\t', engine='python', encoding='utf-8')
#df_reviews = pd.read_csv('reviews_nashville.txt', sep = '\t', engine='python', encoding='utf-8')
df_users = pd.read_csv('users_nashville.txt', sep='\t', engine='python', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File c:\Users\29982\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\python_parser.py:805, in PythonParser._next_iter_line(self, row_num)
#     804 assert self.data is not None
# --> 805 line = next(self.data)
#     806 # for mypy
#
# Error: '	' expected after '"'
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 df_bizs = pd.read_csv('bizs_nashville.txt', sep='\t', engine='python', encoding='utf-8')
# ----> 2 df_reviews = pd.read_csv('reviews_nashville.txt', sep = '\t', engine='python', encoding='utf-8')
#       3 df_users = pd.read_csv('users_nashville.txt', sep='\t', engine='python', encoding='utf-8')
#
# ...

# %% [markdown]
# # 1.数据分析

# %% [markdown]
# # 2. 数据预处理
